# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
import ImageCryptography
import Paillier

# %%
dir = os.listdir("C:\\Users\\Administrator\\Downloads\\Compressed\\Homomorphic-Image-Encryption-master\\Brain_Tumor_Dataset\\")
classes = {"no_tumor":0, "pituitary_tumor":1}

# %%
public_key, private_key = Paillier.generate_keys(bitlen=16)

# %%
file = open('public_key.txt', 'w')

file.write(str(public_key))

file.close()

# %%
from sklearn.decomposition import PCA

# %%
import cv2
c = "no_tumor"
path = "C:\\Users\\Administrator\\Downloads\\Compressed\\Homomorphic-Image-Encryption-master\\Brain_Tumor_Dataset\\Training\\"+c
for x in os.listdir(path):
    img = cv2.imread(path+"/"+x, 0)
    #new
    img = cv2.resize(img, (124,124))
    pca = PCA(32).fit(img) 
    #img_transformed = pca.transform(img)
    #img_transformed = cv2.resize(img_transformed, (124,124)) 
    #print(img.shape)
    #print(img_transformed.shape)
    encryptedimg = ImageCryptography.ImgEncrypt(public_key, img)
    #endnew
    encryptedpath = "C:/Users/Administrator/Downloads/Compressed/Homomorphic-Image-Encryption-master/encrypted-images/Training/"+c+"/"+x+".HE"
    #C:/Users/Administrator/Downloads/Compressed/Homomorphic-Image-Encryption-master/encrypted-images/
    ImageCryptography.saveEncryptedImg(encryptedimg, encryptedpath)
    print("Done")
# Out:
# (124, 124)
# Done
# (124, 124)
# Done
# (124, 124)
# Done
# (124, 124)
# Done
# (124, 124)
# Done
# (124, 124)
# Done
# (124, 124)
# Done
# (124, 124)
# Done
# (124, 124)
# Done
# (124, 124)
# Done
# (124, 124)
# Done
# (124, 124)
# Done
# (124, 124)
# Done
# (124, 124)
# Done
# (124, 124)
# Done
# (124, 124)
# Done
# (124, 124)
# Done
# (124, 124)
# Done
# (124, 124)
# Done
# (124, 124)
# Done
# (124, 124)
# Done
# (124, 124)
# Done
# (124, 124)
# Done
# (124, 124)
# Done
# (124, 124)
# Done
# (124, 124)
# Done
# (124, 124)
# Done
# (124, 124)
# Done
# (124, 124)
# Done
# (124, 124)
# Done
# (124, 124)
# Done
# (124, 124)
# Done
# (124, 124)
# Done
# (124, 124)
# Done
# (124, 124)
# Done
# (124, 124)
# Done
# (124, 124)
# Done
# (124, 124)
# Done
# (124, 124)
# Done
# (124, 124)
# Done
# (124, 124)
# Done
# (124, 124)
# Done
# (124, 124)
# Done
# (124, 124)
# Done
# (124, 124)
# Done
# (124, 124)
# Done
# (124, 124)
# Done
# (124, 124)
# Done
# (124, 124)
# Done
# (124, 124)
# Done
# ...

# %%
print("Okay")

# %%
c = "pituitary_tumor"
path = "C:\\Users\\Administrator\\Downloads\\Compressed\\Homomorphic-Image-Encryption-master\\Brain_Tumor_Dataset\\Training\\"+c
for x in os.listdir(path):
    img = cv2.imread(path+"/"+x, 0)
    #new
    img = cv2.resize(img, (124,124))
    pca = PCA(32).fit(img) 
    #img_transformed = pca.transform(img) 
    encryptedimg = ImageCryptography.ImgEncrypt(public_key, img)
    #endnew
    encryptedpath = "C:/Users/Administrator/Downloads/Compressed/Homomorphic-Image-Encryption-master/encrypted-images/Training/"+c+"/"+x+".HE"
    #C:/Users/Administrator/Downloads/Compressed/Homomorphic-Image-Encryption-master/encrypted-images/
    ImageCryptography.saveEncryptedImg(encryptedimg, encryptedpath)
    print("Done")
# Out:
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# ...

# %%
X = []
Y = []
for c in classes:
    path = "C:\\Users\\Administrator\\Downloads\\Compressed\\Homomorphic-Image-Encryption-master\\encrypted-images\\Training\\"+c
    for x in os.listdir(path):
        encryptedpath = "encrypted-images/Training/"+c+"/"+x
        img = ImageCryptography.loadEncryptedImg(encryptedpath)
        img = cv2.resize(img, (124,124))
        X.append(img)
        Y.append(classes[c])

# %%
X = np.array(X)
print(X[0])
# Out:
# [[-2018030025  1237087006 -1762658455 ...  -544383914   823564036
#   -1281100317]
#  [  983330206   204164032 -1299310639 ... -1962723669   316977470
#    1742092630]
#  [-1362823804    39396310  -918802469 ...  -239349988  -547840201
#     703899361]
#  ...
#  [ -581258049  -412726378  1805617065 ... -1539343630  1941862747
#    -959872889]
#  [  732205080  -536319199  -276556498 ...  2108060755   501466895
#   -1178966942]
#  [  673141700   821425325  1784638507 ... -1104312048 -1578022176
#    1126137898]]

# %%
X = np.array(X)
Y = np.array(Y)
X_reshaped = X.reshape(len(X), -1)
print(X.shape, X_reshaped.shape, np.unique(Y))
# Out:
# (1222, 124, 124) (1222, 15376) [0 1]

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()
scaled = scaler.fit_transform(X_reshaped)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X_reshaped, Y, random_state = 1, test_size = 0.2)

# %%
from sklearn.linear_model import LogisticRegression

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
lg = LogisticRegression(C=1)
lg.fit(X_train, Y_train)
# Out:
# LogisticRegression(C=1)

# %%
print("train score", lg.score(X_train, Y_train))
print("test score", lg.score(X_test, Y_test))
# Out:
# train score 1.0
# test score 0.5102040816326531

# %%
from sklearn.svm import SVC

# %%
sv = SVC()
sv.fit(X_train, Y_train)
# Out:
# SVC()

# %%
print("train score", sv.score(X_train, Y_train))
print("test score", sv.score(X_test, Y_test))
# Out:
# train score 1.0
# test score 0.6653061224489796

# %%
from sklearn.tree import DecisionTreeClassifier
dtc = DecisionTreeClassifier()
dtc.fit(X_train, Y_train)
# Out:
# DecisionTreeClassifier()

# %%
print("train score", dtc.score(X_train, Y_train))
print("test score", dtc.score(X_test, Y_test))
# Out:
# train score 1.0
# test score 0.5755102040816327

# %%
from sklearn.ensemble import RandomForestClassifier
rfc = RandomForestClassifier()
rfc.fit(X_train, Y_train)
# Out:
# RandomForestClassifier()

# %%
print("train score", rfc.score(X_train, Y_train))
print("test score", rfc.score(X_test, Y_test))
# Out:
# train score 1.0
# test score 0.6653061224489796

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier()
knn.fit(X_train, Y_train)
# Out:
# KNeighborsClassifier()

# %%
print("train score", knn.score(X_train, Y_train))
print("test score", knn.score(X_test, Y_test))
# Out:
# train score 0.7584442169907881
# test score 0.6448979591836734

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
gnb.fit(X_train, Y_train)
# Out:
# GaussianNB()

# %%
print("train score", gnb.score(X_train, Y_train))
print("test score", gnb.score(X_test, Y_test))
# Out:
# train score 1.0
# test score 0.6612244897959184
